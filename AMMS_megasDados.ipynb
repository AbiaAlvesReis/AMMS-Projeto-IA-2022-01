# %% [markdown]
# <a href="https://colab.research.google.com/github/AbiaAlvesReis/Projeto-IA-2022-01/blob/main/AMMS_megasDados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Dados e Estatística da Loteria Mega-Sena**
#
#  Atualizada até 04/06/2022

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
mega_df = pd.read_excel('/content/drive/MyDrive/2022/IA - projeto/megas.xlsx', parse_dates=True, index_col=1)

# %%
# Número de linhas e de colunas
mega_df.shape
# Out:
# (2484, 7)

# %%
mega_df.dropna(inplace=True)
mega_df.drop('lottery', inplace=True, axis=1)
mega_df.head()
# Out:
#               ball_01  ball_02  ball_03  ball_04  ball_05  ball_06
# date_occured
# 2022-05-25       59.0     36.0     41.0     54.0     14.0     11.0
# 2022-05-21       54.0     49.0     34.0     38.0     40.0     20.0
# 2022-05-18       32.0      1.0     57.0     44.0     35.0     45.0
# 2022-05-14        1.0     37.0     36.0     21.0      8.0     27.0
# 2022-11-05       31.0     56.0      6.0      4.0     50.0      9.0

# %%
mega_df.describe()
# Out:
#            ball_01      ball_02      ball_03      ball_04      ball_05  \
# count  2484.000000  2484.000000  2484.000000  2484.000000  2484.000000
# mean     30.453301    30.159018    30.731481    30.746377    30.565217
# std      17.295606    17.366813    17.331223    17.249376    17.170328
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%      16.000000    15.000000    16.000000    16.000000    15.000000
# 50%      30.000000    31.000000    31.000000    31.000000    31.000000
# 75%      45.000000    45.000000    45.250000    45.000000    45.000000
# max      60.000000    60.000000    60.000000    60.000000    60.000000
#
#            ball_06
# count  2484.000000
# mean     30.371578
# std      17.177335
# min       1.000000
# 25%      16.000000
# 50%      30.000000
# 75%      45.000000
# max      60.000000

# %% [markdown]
# # **A questão da natureza dos números aleatórios**
#
# Não existe um padrão no gráfico

# %%
ax = mega_df.plot(kind='line', figsize=(25,12))
plt.show()

# %%
plot_cols = ['ball_01', 'ball_02', 'ball_03', 'ball_04', 'ball_05', 'ball_06']
plot_features = mega_df[plot_cols]
_ = plot_features.plot(subplots=True, figsize=(25,12))

# %%
import matplotlib.pyplot as plt

mega_df.hist(column='ball_01',bins = 100)
plt.title('Primeira bola sorteada')
plt.ylabel('Total de vezes sorteada')
plt.xlabel('Número da bola')
plt.xlim(1, 60)
plt.ylim(1, 250)
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
mega_df.hist(column='ball_02',bins = 100)
plt.title('Segunda bola sorteada')
plt.ylabel('Total de vezes sorteada')
plt.xlabel('Número da bola')
plt.xlim(1, 60)
plt.ylim(1, 250)
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
mega_df.hist(column='ball_03',bins = 100)
plt.title('Terceira bola sorteada')
plt.ylabel('Total de vezes sorteada')
plt.xlabel('Número da bola')
plt.xlim(1, 60)
plt.ylim(1, 250)
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
mega_df.hist(column='ball_04',bins = 100)
plt.title('Quarta bola sorteada')
plt.ylabel('Total de vezes sorteada')
plt.xlabel('Número da bola')
plt.xlim(1, 60)
plt.ylim(1, 250)
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
mega_df.hist(column='ball_05',bins = 100)
plt.title('Quinta bola sorteada')
plt.ylabel('Total de vezes sorteada')
plt.xlabel('Número da bola')
plt.xlim(1, 60)
plt.ylim(1, 250)
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
mega_df.hist(column='ball_06',bins = 100)
plt.title('Sexta bola sorteada')
plt.ylabel('Total de vezes sorteada')
plt.xlabel('Número da bola')
plt.xlim(1, 60)
plt.ylim(1, 250)
plt.grid(True)
plt.show()

# %%
numero_01 = mega_df.loc[mega_df['ball_01']==1]
#numero_01 = mega_df.loc[mega_df['ball_01']==1]
print(numero_01)
# Out:
#               ball_01  ball_02  ball_03  ball_04  ball_05  ball_06
# date_occured
# 2022-05-14        1.0     37.0     36.0     21.0      8.0     27.0
# 2022-03-30        1.0     10.0     45.0     19.0     35.0     34.0
# 2020-08-26        1.0     48.0     42.0     10.0      2.0     37.0
# 2020-01-18        1.0     37.0     47.0     44.0     46.0     32.0
# 2018-11-24        1.0     35.0     13.0     11.0     10.0     49.0
# 2018-01-31        1.0     48.0     50.0     44.0     37.0     46.0
# 2016-02-27        1.0      5.0     37.0     60.0     34.0     40.0
# 2016-04-02        1.0     29.0     13.0     25.0      5.0     26.0
# 2015-12-26        1.0     52.0     30.0     60.0     20.0     12.0
# 2015-11-28        1.0     28.0     56.0     37.0      6.0     58.0
# 2015-06-08        1.0     24.0     10.0     17.0     42.0     51.0
# 2015-04-29        1.0     10.0     30.0     33.0     38.0      6.0
# 2015-02-25        1.0     33.0      8.0     11.0      6.0     50.0
# ...

# %%
df = mega_df
count_draw1 = df['ball_01'].value_counts().to_dict()
count_draw2 = df['ball_02'].value_counts().to_dict()
count_draw3 = df['ball_03'].value_counts().to_dict()
count_draw4 = df['ball_04'].value_counts().to_dict()
count_draw5 = df['ball_05'].value_counts().to_dict()
count_draw6 = df['ball_06'].value_counts().to_dict()

powerball = pd.DataFrame([count_draw1, count_draw2, count_draw3, count_draw4, count_draw5, count_draw6]) 
powerball = powerball.sort_index(axis=1)
pw = powerball
pw = pw.T
pw.columns = ['total primeira','total segunda','total terceira','total quarta','total quinta','total sexta']
pw['SUPER_TOTAL'] = pw.sum(axis=1)
pw

print(pw['SUPER_TOTAL'])
# Out:
# 1.0     241
# 2.0     255
# 3.0     228
# 4.0     265
# 5.0     271
# 6.0     250
# 7.0     236
# 8.0     252
# 9.0     233
# 10.0    282
# 11.0    259
# 12.0    239
# 13.0    253
# 14.0    233
# 15.0    219
# 16.0    258
# 17.0    259
# 18.0    244
# 19.0    235
# 20.0    241
# 21.0    214
# 22.0    218
# 23.0    266
# 24.0    256
# 25.0    236
# 26.0    205
# 27.0    262
# 28.0    263
# 29.0    259
# 30.0    264
# 31.0    234
# 32.0    256
# 33.0    267
# 34.0    261
# 35.0    263
# 36.0    256
# 37.0    270
# 38.0    257
# 39.0    235
# 40.0    239
# 41.0    262
# 42.0    272
# 43.0    257
# 44.0    260
# 45.0    240
# 46.0    248
# 47.0    237
# 48.0    228
# 49.0    258
# 50.0    244
# 51.0    258
# 52.0    249
# 53.0    284
# 54.0    263
# 55.0    211
# 56.0    253
# 57.0    236
# 58.0    241
# 59.0    234
# 60.0    235
# Name: SUPER_TOTAL, dtype: int64

# %%
 # https://matplotlib.org/
 import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(12, 24))

group_data = list(pw['SUPER_TOTAL'])
group_names = list(pw.keys())

pw['SUPER_TOTAL'].plot.barh(group_names, group_data)
plt.style.use('bmh')
ax.set(xlim=[180, 300], xlabel='Número de reptições', ylabel='Dezenas',title='Repetições')
# Out:
# [Text(0, 0.5, 'Dezenas'),
#  (180.0, 300.0),
#  Text(0.5, 0, 'Número de reptições'),
#  Text(0.5, 1.0, 'Repetições')]

# %%
 # Criando Dataframe com base na contagem de vezes que aparece cada número

c = pw.T
x01 = c[1] + c[2] + c[3] + c[4] + c[5] + c[6] + c[7] + c[8] + c[9] + c[10]
x11 = c[11] + c[12] + c[13] + c[14] + c[15] + c[16] + c[17] + c[18] + c[19] + c[20]
x21 = c[21] + c[22] + c[23] + c[24] + c[25] + c[26] + c[27] + c[28] + c[29] + c[30]
x31 = c[31] + c[32] + c[33] + c[34] + c[35] + c[36] + c[37] + c[38] + c[39] + c[40]
x41 = c[41] + c[42] + c[43] + c[44] + c[45] + c[46] + c[47] + c[48] + c[49] + c[50]
x51 = c[51] + c[52] + c[53] + c[54] + c[55] + c[56] + c[57] + c[58] + c[59] + c[60]

dezenas = pd.DataFrame([x01, x11, x21, x31, x41, x51])
dezenas = dezenas.T
dezenas.columns = ['n1-10','n11-20','n21-30','n31-40','n41-50','n51-60']
dezenas = dezenas.T
dezenas
# Out:
#         total primeira  total segunda  total terceira  total quarta  \
# n1-10              427            447             395           413
# n11-20             401            402             426           396
# n21-30             415            390             416           413
# n31-40             412            412             413           431
# n41-50             424            439             391           409
# n51-60             405            394             443           422
#
#         total quinta  total sexta  SUPER_TOTAL
# n1-10            414          417         2513
# n11-20           413          402         2440
# n21-30           381          428         2443
# n31-40           446          424         2538
# n41-50           434          409         2506
# n51-60           396          404         2464
